# %% [markdown]
# # Q1. What is an Exception in python? Write the difference between Exceptions and Syntax errors.
# Exceptions are runtime errors that occur during the execution of a program, while syntax errors are errors that prevent the program from running at all because the code is invalid.
# # Q2. What happens when an exception is not handled? Explain with an example.
# When an exception is not handled in a Python program, it results in the program terminating and displaying an error message that indicates the type of exception that occurred, as well as the location in the code where the exception occurred. This can make it difficult for users to understand the cause of the error and can also result in the loss of any unsaved data or incomplete operations.

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
    print("Result is", result)
except Exception as e:
    print("Invalid input. You must enter an integer.")
# Out:
# Enter a number: 0
# Invalid input. You must enter an integer.

# %% [markdown]
# # Q3. Which Python statements are used to catch and handle exceptions? Explain with an example.
# try and except statement used to catch and handle exception.
# for ex: refer Q2

# %% [markdown]
# # Q4. Explain with an example:
# 1. try and else
#
# If try executed successfully without error then else statement will execute otherwise not
#
# 2. finally
#
# finally will execute itself in any situation
#
# 3. raise
#
# raise will return statement according to condition

# %%
def valid_height(i):
    if i<=0 :
        raise valid_height("Enter valid height")
    elif i>8:
        raise valid_height(f"{i}foot is not normal please confirm your height by using foot scale")

# %%
try : 
    height = float(input("What is your Height"))
    valid_height(height)
except exception as e:
    print("except:  Only Numbers are allowed",e)
else:
    print(f"else:  you entered height {height}ft")
finally:
    print("finally:  Thanks for giving your precious time")
# Out:
# What is your Height6
# else:  you entered height 6.0ft
# finally:  Thanks for giving your precious time

# %% [markdown]
# # Q5. What are Custom Exceptions in python? Why do we need Custom Exceptions? Explain with an example.
# Customize the those exception which are not built in .
#
# Custom exceptions can be useful in several ways, such as:
#
# Adding more clarity to the error messages generated by the program
#
# Making it easier to handle specific exceptions in a more controlled way
#
# Enabling the reuse of code by encapsulating similar exceptions into a single custom exception

# %%
class NegativeNumberError(Exception):
    def __init__(self, message):
        super().__init__(message)
        self.message = message

    def __str__(self):
        return f"{self.message}: Number cannot be negative"

# %% [markdown]
# # Q6. Create a custom exception class. Use this class to handle an exception.

# %%
class InvalidInputError(Exception):
    """Exception raised when input is invalid"""

    def __init__(self, message):
        super().__init__(message)
        self.message = message

def divide_numbers(num1, num2):
    if num2 == 0:
        raise InvalidInputError("Invalid input: denominator cannot be zero")
    else:
        return num1 / num2

try:
    result = divide_numbers(10, 0)
    print(result)
except InvalidInputError as e:
    print(e.message)
# Out:
# Invalid input: denominator cannot be zero
