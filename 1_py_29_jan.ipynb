# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 1. `Guido van Rossum` developed Python Programming Language
# - 2.  It supports `multiple programming paradigms`, including `structured` (particularly procedural), `object-oriented` and `functional programming`
# - 3. Yes python is a `case-sensitive language`
# - 4. Some popular extension of python are `.py or .ipyb` and some other extension also used for python such as(.pyi, .pyc, .pyd, .pyo, .pyw, and .pyz)
# - 5. Yes, Python is both compiled as well as an interpreted language, which means when we run a python code, it is first compiled and then interpreted line by line
# - 6. A Python program is constructed from code blocks. A block is a piece of Python program text that is executed as a unit. The following are blocks: a module, a function body, and a class definition. Each command typed interactively is a block.
# - 7.`#` is used for single-line comment.

# %%
# 8. Python version 
import sys
sys.version
# Out:
# '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]'

# %% [markdown]
# - 9. `lambda` is a `anonymous` function there is no need to name the function.
# - 10. pip stands for `Preferred Installer Program` allows you to install and manage packages that aren't part of the Python standard library.

# %% [markdown]
# # 11. some built in function in python are:
# - print( ) function.
# - type( ) function.
# - input( ) function.
# - len() function.
# - sum() function.

# %% [markdown]
# - 12. An identifier can have a maximum length of 79 characters in Python.

# %% [markdown]
# # 13. Python Benefits
# - free and open source
# - easy to learn and fun to use. Its syntax, unlike most computer languages, reads like English, so it isn’t as stressful to learn as other programming languages.

# %% [markdown]
# # 14. Memory management in Python
# - Memory management in Python involves a private heap containing all Python objects and data structures. The management of this private heap is ensured internally by the Python memory manager. The Python memory manager has different components which deal with various dynamic storage management aspects, like sharing, segmentation, preallocation or caching.

# %% [markdown]
# # 15.
# Python can istall from official site <https://www.python.org/downloads/> and set path variable by following step:
# - Right-clicking This PC and going to Properties.
#
# - Clicking on the Advanced system settings in the menu on the left.
#
# - Clicking on the Environment Variables button o​n the bottom right.
#
# - In the System variables section, selecting the Path variable and clicking on Edit. The next screen will show all the directories that are currently a part of the PATH variable.
#
# - Clicking on New and entering Python’s install directory.

# %% [markdown]
# ### 16. Yes indentation is required if you want to mention something in a block(:) unwanted indentation or space can give error
